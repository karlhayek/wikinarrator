# %%
import pywikibot
from pywikibot import textlib
site = pywikibot.Site('wikipedia:fr')  # create a Site object
page = pywikibot.Page(site, 'Deep learning')  # create a Page object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=0'>1</a> import pywikibot
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=1'>2</a> from pywikibot import textlib
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=2'>3</a> site = pywikibot.Site('wikipedia:fr')  # create a Site object
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=3'>4</a> page = pywikibot.Page(site, 'Deep learning')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pywikibot/tools/_deprecate.py:404, in deprecated_args.<locals>.decorator.<locals>.wrapper(*__args, **__kw)
# ...

# %%
import mwparserfromhell

# %%
text = """Le '''jazz''' est un [[genre musical]] originaire du [[Sud des États-Unis|Sud]] des [[États-Unis]], créé à la fin du {{s|XIX}} et au début du {{s|XX}} au sein des communautés [[Afro-Américains|afro-américaines]]. Avec plus de cent ans d'existence, du [[ragtime]] au jazz actuel, il recouvre de nombreux sous-genres marqués par un héritage de la musique [[Euro-Américains|euro-américaine]] et [[Musique afro-américaine|afro-américaine]], et conçus pour être joués en public<ref name=":4">{{Ouvrage|langue=en|auteur1=Thomas Hennessey|titre=From Jazz to Swing|sous-titre=Black Jazz Musicians and Their Music|éditeur=Northwestern University|année=1973|passage=pp. 470-473|isbn=}}.</ref>. Il émerge à partir d'autres genres musicaux, dont le ragtime, la [[Marche (musique)|marche]], le ''[[negro spiritual]]'' et le [[blues]], et comporte des caractéristiques telles que l'utilisation fréquente de l'[[Improvisation musicale|improvisation]], de la [[polyrythmie]], de la [[Syncope (musique)|syncope]], du ''[[Shuffle (musique)|shuffle]]'', du ''[[scat]]'' et des [[Note bleue|notes bleues]]<ref>{{Ouvrage|langue=en|auteur1=Alyn Shipton|titre=A New History of Jazz|éditeur=Continuum|année=2007|passage=pp. 4-5|isbn=}}.</ref>. En route, il emprunte de nombreux éléments à la {{Lien|trad=American popular music|lang=en|fr=Musique populaire américaine|texte=musique populaire américaine}} et à la tradition des ''[[brass band]]s''<ref>{{Ouvrage|langue=en|auteur1=Bill Kirchner|titre=The Oxford Companion to Jazz|lieu=Oxford|éditeur=[[Oxford University Press]]|année=2005|passage=Chapitre 2|isbn=}}.</ref>. Couramment associé aux cinq instruments emblématiques du jazz — le [[saxophone]], la [[trompette]], le [[Trombone (instrument)|trombone]], la [[clarinette]] et le [[piano]] —, le jazz mobilise cependant un grand nombre d'instruments différents, dont la [[guitare]], la [[Batterie (musique)|batterie]], et la [[contrebasse]].

Au cours du {{s|XX}}, le jazz a acquis une large popularité au-delà des frontières des États-Unis et s'est répandu dans le monde, donnant naissance à de très nombreux styles et sous-genres selon les pays et les régions. Les premières formes de jazz apparaissent à [[la Nouvelle-Orléans]] et à [[Saint-Louis (Missouri)|Saint-Louis]] dès 1910 : le [[jazz Nouvelle-Orléans]] mélange le blues à la [[Quadrille (danse)|quadrille]] et la [[biguine]] des Antilles françaises. Dans les [[années 1930]] émergent le [[swing (musique)|swing]], un style marqué par le blues et l'improvisation, et le [[jazz manouche]], un genre créé en France sous l'influence des ''[[big band]]s'' et du [[bal musette]]. D'une musique populaire conçue pour la danse, le jazz devient un genre musical complexe avec le [[bebop]], joué à des [[tempo]]s plus rapides et avec des accords plus élaborés. Le [[cool jazz]] de la fin des [[années 1940]] apporte des sons calmes, délicats, et des mélodies longues et linéaires. Le [[free jazz]] des [[années 1950]] se libère quant à lui des contraintes harmoniques, et met en valeur l'improvisation et l'énergie.
"""

text = """
Le jazz est un mélange de courants musicaux très divers. Au cours de son évolution, il a su intégrer de nombreuses influences et se prêter à de nombreux métissages, comme le blues, le rock, la musique latine, le hard rock, et ainsi de suite. Du point de vue de la technique musicale, sa richesse et sa complexité sont aujourd'hui telles qu'il est difficile de décrire précisément ce qui le caractérise. Le jazz comprend une grande variété de sous-types, comme traditionnel, be-bop, fusion, free-jazz{{etc.}} D'après Travis Jackson, le jazz peut être défini d'une façon plus « ouverte », en disant que le jazz (soit qu'on parle de swing, fusion, ou latin-jazz) est une musique qui inclut souvent des qualités comme le ''swing'', l'improvisation, l'interaction en groupe, le développement d'une voix individuelle comme artiste, et qui est ouverte aux diverses possibilités musicales<ref>Critique de ''The Cambridge Companion to Jazz'' par Peter Elsdon, ''Frankfurter Zeitschrift für Musikwissenschaft'' (Revue de Francfort de musicologie), no. 6, 2003.</ref>.

Les éléments distinctifs suivants se retrouvent dans la majorité des styles de jazz :
* Le [[Swing (musique)|swing]] : c'est une division du temps ternaire dans laquelle 2 croches se jouent noire-croche dans un triolet, division du temps 2/3-1/3, le fameux « chabada », donnant ainsi un rythme entraînant spécifique au jazz ;
* L'accentuation des temps faibles (l'inverse de la musique classique) ;
* L'abondanc
"""

# %%
mwparserfromhell.parse().strip_code()
# Out:
# "Le jazz est un mélange de courants musicaux très divers. Au cours de son évolution, il a su intégrer de nombreuses influences et se prêter à de nombreux métissages, comme le blues, le rock, la musique latine, le hard rock, et ainsi de suite. Du point de vue de la technique musicale, sa richesse et sa complexité sont aujourd'hui telles qu'il est difficile de décrire précisément ce qui le caractérise. Le jazz comprend une grande variété de sous-types, comme traditionnel, be-bop, fusion, free-jazz D'après Travis Jackson, le jazz peut être défini d'une façon plus « ouverte », en disant que le jazz (soit qu'on parle de swing, fusion, ou latin-jazz) est une musique qui inclut souvent des qualités comme le swing, l'improvisation, l'interaction en groupe, le développement d'une voix individuelle comme artiste, et qui est ouverte aux diverses possibilités musicalesCritique de The Cambridge Companion to Jazz par Peter Elsdon, Frankfurter Zeitschrift für Musikwissenschaft (Revue de Francfort d
# ...
