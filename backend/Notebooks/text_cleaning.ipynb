# %%
import re, sys
from mediawiki import MediaWiki
import wikipediaapi
from itertools import chain

# Change path to access app code
sys.path.append('../app')
import text_cleaner
import main

# %%
wiki = MediaWiki(lang="fr")

wiki_wiki = wikipediaapi.Wikipedia(
    language='fr',
    extract_format=wikipediaapi.ExtractFormat.HTML
    # extract_format=wikipediaapi.ExtractFormat.WIKI
)

page_query = "vera rubin"
page_query = "albert einstein"
title = main.get_exact_title(page_query)

# %%
# Retrieve html text
page = wiki_wiki.page(title)
text = page.text

# %%
print(text)
# Out:
# <p class="mw-empty-elt">
# </p>
#
#
# ...

# %% [markdown]
# ### Wikipedia api test

# %%
text
# Out:
# '<p class="mw-empty-elt">\n</p>\n\n\n<p><b>Albert Einstein</b> (prononcé en allemand <span title="Alphabet phonétique international">[<span title="[ˈ] indique que la syllabe ou voyelle suivante porte l\'accent tonique.">ˈ</span><span title="[a] « a » dans « patte ».">a</span><span title="[l] « l » dans « loup ».">l</span><span title="[b] « b » dans « beau ».">b</span>ɐ<span title="[t] en français « t » dans « tous » ; ailleurs avec la langue un peu plus en arrière.">t</span> <span title="[ˈ] indique que la syllabe ou voyelle suivante porte l\'accent tonique.">ˈ</span><span title="[a] « a » dans « patte ».">a</span>ɪ<span title="[n] en français « n » dans « nous » ; ailleurs avec la langue un peu plus en arrière.">n</span><span title="[ʃ] « ch » dans « chou ».">ʃ</span><span title="[t] en français « t » dans « tous » ; ailleurs avec la langue un peu plus en arrière.">t</span><span title="[a] « a » dans « patte ».">a</span>ɪ<span title="[n] en français « n » dans « nous » ; ailleurs av
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(text, 'html.parser')

print(soup.get_text())
# Out:
# Albert Einstein (prononcé en allemand [ˈalbɐt ˈaɪnʃtaɪn] ) né le 14 mars 1879 à Ulm, dans le Wurtemberg (Empire allemand), et mort le 18 avril 1955 à Princeton, dans le New Jersey (États-Unis), est un physicien théoricien. Il fut successivement allemand, apatride (entre 1896 et 1901), suisse (1901) et de double nationalité helvético-américaine (1940). Il épousa Mileva Marić, puis sa cousine Elsa Einstein.
# Il publie sa théorie de la relativité restreinte en 1905 et sa théorie de la gravitation, dite relativité générale, en 1915. Il contribue largement au développement de la mécanique quantique et de la cosmologie, et reçoit le prix Nobel de physique de 1921 pour son explication de l’effet photoélectrique. Son travail est notamment connu du grand public pour l’équation E=mc2, qui établit une équivalence entre la masse et l’énergie d’un système.
# ...

# %%
t = """<p><b>Albert Einstein</b> (prononcé en allemand <span title="Alphabet phonétique international">[<span title="[ˈ] indique que la syllabe ou voyelle suivante porte l'accent tonique.">ˈ</span><span title="[a] « a » dans « patte ».">a</span><span title="[l] « l » dans « loup ».">l</span><span title="[b] « b » dans « beau ».">b</span>ɐ<span title="[t] en français « t » dans « tous » ; ailleurs avec la langue un peu plus en arrière.">t</span> <span title="[ˈ] indique que la syllabe ou voyelle suivante porte l'accent tonique.">ˈ</span><span title="[a] « a » dans « patte ».">a</span>ɪ<span title="[n] en français « n » dans « nous » ; ailleurs avec la langue un peu plus en arrière.">n</span><span title="[ʃ] « ch » dans « chou ».">ʃ</span><span title="[t] en français « t » dans « tous » ; ailleurs avec la langue un peu plus en arrière.">t</span><span title="[a] « a » dans « patte ».">a</span>ɪ<span title="[n] en français « n » dans « nous » ; ailleurs avec la langue un peu plus en arrière.">n</span>]</span> ) né le <time class="nowrap date-lien bday" datetime="1879-03-14" data-sort-value="1879-03-14">14 mars 1879</time> à Ulm, dans le Wurtemberg (Empire allemand), et mort le <time class="nowrap date-lien dday" datetime="1955-04-18" data-sort-value="1955-04-18">18 avril 1955</time> à Princeton, dans le New Jersey (États-Unis), est un physicien théoricien. Il fut successivement allemand, apatride (entre 1896 et 1901), suisse (1901) et de double nationalité helvético-américaine (1940). Il épousa Mileva Marić, puis sa cousine Elsa Einstein.
</p><p>Il publie sa théorie de la relativité restreinte en 1905 et sa théorie de la gravitation, dite relativité générale, en 1915. Il contribue largement au développement de la mécanique quantique et de la cosmologie, et reçoit le prix Nobel de physique de 1921 pour son explication de l’effet photoélectrique. Son travail est notamment connu du grand public pour l’équation <i>E</i>=<i>mc</i><sup>2</sup>, qui établit une équivalence entre la masse et l’énergie d’un système.
</p>"""

t = text_cleaner.edit_and_convert_html_text(t)
t = text_cleaner.clean_text(t)
# t = text_cleaner.prepare_text_for_TTS(t)
t
# Out:
# 'Albert Einstein (prononcé en allemand [ˈalbɐt ˈaɪnʃtaɪn] ) né le 14 mars 1879 à Ulm, dans le Wurtemberg (Empire allemand), et mort le 18 avril 1955 à Princeton, dans le New Jersey (États-Unis), est un physicien théoricien. Il fut successivement allemand, apatride (entre 1896 et 1901), suisse (1901) et de double nationalité helvético-américaine (1940). Il épousa Mileva Marić, puis sa cousine Elsa Einstein.\nIl publie sa théorie de la relativité restreinte en 1905 et sa théorie de la gravitation, dite relativité générale, en 1915. Il contribue largement au développement de la mécanique quantique et de la cosmologie, et reçoit le prix Nobel de physique de 1921 pour son explication de l’effet photoélectrique. Son travail est notamment connu du grand public pour l’équation E=mc2, qui établit une équivalence entre la masse et l’énergie d’un système.\n'

# %%
for h2 in soup.find_all("h2"):
    h2.insert_before("\n== ")
    h2.insert_after(" ==\n")

# %%
t = """ <ul class="gallery mw-gallery-packed"><li class="gallerybox" style="width: 96px">
		<li class="gallerybox" style="width: 155.33333333333px">
		<li class="gallerybox" style="width: 85.333333333333px">
		<li class="gallerybox" style="width: 84px">
		<li class="gallerybox" style="width: 108px">
		<li class="gallerybox" style="width: 86.666666666667px">
</ul> """

# %%
# %%timeit
soup.select("ul.gallery")
# soup.findAll(lambda tag: tag.name == 'ul' and (tag.has_attr("class") and "gallery" in tag.attrs['class']))
# Out:
# 3.09 ms ± 137 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s = BeautifulSoup(t, 'html.parser')
s.select_one("li.gallerybox")
# Out:
# <li class="gallerybox" style="width: 96px">
# <li class="gallerybox" style="width: 155.33333333333px">
# <li class="gallerybox" style="width: 85.333333333333px">
# <li class="gallerybox" style="width: 84px">
# <li class="gallerybox" style="width: 108px">
# <li class="gallerybox" style="width: 86.666666666667px">
# </li></li></li></li></li></li>

# %%
s = BeautifulSoup(t, 'html.parser')
for ul in soup.select("ul.gallery"):
# for ul in s.findAll(lambda tag: tag.name == 'ul' and (tag.has_attr("class") and "gallerybox" in tag.attrs['class'])):
    # Remove tag
    ul.extract()

# %%
s.get_text()
# Out:
# ' \n\n\n\n\n\n '

# %%
soup.find_all("sup", attrs="reference cite_virgule")
# Out:
# [<sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>,
#  <sup class="reference cite_virgule">,</sup>]

# %%
text = "JavaScript flavors of RegEx are supported. Validate your expression with Tests mode. 2/3 and view patterns you create or favorite in My Patterns. 21 things to think about 32\n123413/442"

replace_list_regex = {
        r"Mc(?=[A-Z][a-z]+)": "Mac",    # McGellan -> MacGellan
        r"(?!\d+)\/(?=\d+)":  " sur ",  # nombres séparés par '/'
    }
for regex_to_replace, replacer in replace_list_regex.items():
    text = re.sub(regex_to_replace, replacer, text)


text
# Out:
# 'JavaScript flavors of RegEx are supported. Validate your expression with Tests mode. 2 sur 3 and view patterns you create or favorite in My Patterns. 21 things to think about 32\n123413 sur 442'

# %%
print(soup.get_text())
# Out:
# Albert Einstein (prononcé en allemand [ˈalbɐt ˈaɪnʃtaɪn] ) né le 14 mars 1879 à Ulm, dans le Wurtemberg (Empire allemand), et mort le 18 avril 1955 à Princeton, dans le New Jersey (États-Unis), est un physicien théoricien. Il fut successivement allemand, apatride (entre 1896 et 1901), suisse (1901) et de double nationalité helvético-américaine (1940). Il épousa Mileva Marić, puis sa cousine Elsa Einstein.
# Il publie sa théorie de la relativité restreinte en 1905 et sa théorie de la gravitation, dite relativité générale, en 1915. Il contribue largement au développement de la mécanique quantique et de la cosmologie, et reçoit le prix Nobel de physique de 1921 pour son explication de l’effet photoélectrique. Son travail est notamment connu du grand public pour l’équation E=mc2, qui établit une équivalence entre la masse et l’énergie d’un système.
# ...

# %% [markdown]
# Extracting the table of contents

# %%
## Get table of contents 

from bs4 import BeautifulSoup

page = wiki.page('jazz')

page_html = page.html

soup = BeautifulSoup(page_html, 'html.parser')

# %%
soup.find(id="toc")
# Out:
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="fr"><h2 id="mw-toc-heading">Sommaire</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Caractéristiques"><span class="tocnumber">1</span> <span class="toctext">Caractéristiques</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Caractéristiques_générales"><span class="tocnumber">1.1</span> <span class="toctext">Caractéristiques générales</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Importance_de_l'improvisation"><span class="tocnumber">1.2</span> <span class="toctext">Importance de l'improvisation</span></a></li>
# ...

# %%
page.table_of_contents
# Out:
# OrderedDict([('Caractéristiques',
#               OrderedDict([('Caractéristiques générales', OrderedDict()),
#                            ("Importance de l'improvisation", OrderedDict()),
#                            ('Débats', OrderedDict())])),
#              ('Étymologie', OrderedDict()),
#              ('Histoire',
#               OrderedDict([('Origines',
#                             OrderedDict([('Musique et danses des esclaves',
#                                           OrderedDict()),
#                                          ('Influences afro-caribéennes',
#                                           OrderedDict())])),
#                            ('Ragtime et blues (1890-1910)', OrderedDict()),
#                            ('Jazz Nouvelle-Orléans et Dixieland (1910-1930)',
#                             OrderedDict()),
#                            ('Du swing au bebop', OrderedDict()),
# ...
